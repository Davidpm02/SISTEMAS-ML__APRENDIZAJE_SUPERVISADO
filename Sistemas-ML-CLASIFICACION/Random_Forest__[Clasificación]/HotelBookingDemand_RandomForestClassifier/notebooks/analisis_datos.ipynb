# %% [markdown]
# # Objetivo del notebook
#
# El objetivo principal de este notebook no es otro que el de analizar los datos de los que partimos para desarrollar el sistema de prediccion.

# %% [markdown]
# # Importar las librerias a utilizar

# %%
import pandas as pd
import numpy as np

# %%
# Cargo el conjunto de datos en memoria como un objeto DataFrame
dataset_route = '../data/hotel_bookings_clean.csv'
bookings_df = pd.read_csv(dataset_route)

# Muestro los 10 primeros registros del dataset
bookings_df.head(10)
# Out:
#    is_canceled  lead_time  arrival_date_week_number  \
# 0            0        342                        27
# 1            0        737                        27
# 2            0          7                        27
# 3            0         13                        27
# 4            0         14                        27
# 5            0         14                        27
# 6            0          0                        27
# 7            0          9                        27
# 8            1         85                        27
# 9            1         75                        27
#
#    arrival_date_day_of_month  arrival_date_month  stays_in_weekend_nights  \
# 0                          1                   7                        0
# 1                          1                   7                        0
# 2                          1                   7                        0
# 3                          1                   7                        0
# ...

# %%
# Muestro los ultimos 10 registros del dataset
bookings_df.tail(10)
# Out:
#         is_canceled  lead_time  arrival_date_week_number  \
# 119200            0         44                        35
# 119201            0        188                        35
# 119202            0        135                        35
# 119203            0        164                        35
# 119204            0         21                        35
# 119205            0         23                        35
# 119206            0        102                        35
# 119207            0         34                        35
# 119208            0        109                        35
# 119209            0        205                        35
#
#         arrival_date_day_of_month  arrival_date_month  \
# 119200                         31                   8
# 119201                         31                   8
# 119202                         30                   8
# 119203                         31                   8
# 119204                         30                   8
# ...

# %%
# Muestro informacion del dataframe
bookings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119210 entries, 0 to 119209
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   is_canceled                     119210 non-null  int64
#  1   lead_time                       119210 non-null  int64
#  2   arrival_date_week_number        119210 non-null  int64
#  3   arrival_date_day_of_month       119210 non-null  int64
#  4   arrival_date_month              119210 non-null  int64
#  5   stays_in_weekend_nights         119210 non-null  int64
#  6   stays_in_week_nights            119210 non-null  int64
#  7   adults                          119210 non-null  int64
#  8   children                        119206 non-null  float64
#  9   babies                          119210 non-null  int64
#  10  is_repeated_guest               119210 non-null  int64
#  11  previous_cancellations          119210 non-null  int64
# ...

# %% [markdown]
# Como se indica en el README adjunto a este analisis, y por tanto, en la descripcion de este conjunto de datos, los datos se encuentran procesados, por lo que no va a ser necesario aplicar preprocesamiento de datos (a excepcion de normalizacion, en columnas en las que esta fuese necesaria).
#
# Por otro lado, podemos ver como dos de las columnas de nuestro dataset almacenan valores de tipo entero, mientras que el resto de columnas, almacenan varioes de tipo flotante.
#
# Por su parte, contamos con unicamente 4 valores nulos registrados en nuestro dataframe. Si es cierto que podria aplicar KNN para estimar los valores faltantes de esta variable, pero al tratarse de la variable 'children', y ser solo 4 ejemplos, voy a optar por eliminar dichos registros de mi dataset.

# %%
print(bookings_df.isna().sum())
bookings_df.dropna(inplace = True)
# Out:
# is_canceled                       0
# lead_time                         0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# arrival_date_month                0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# required_car_parking_spaces       0
# total_of_special_requests         0
# avg_daily_rate                    0
# booked_by_company                 0
# booked_by_agent                   0
# hotel_City                        0
# hotel_Resort                      0
# meal_BB                           0
# meal_FB                           0
# meal_HB                           0
# meal_No_meal                      0
# market_segment_Aviation           0
# market_segment_Complementary      0
# ...

# %% [markdown]
# Voy a continuar con el analisis de los datos a partir de visualizar distribuciones de los mismos en funcion de algunas de las caracteristicas que tenemos recogidas.
# Continuo en el notebook 'visualizacion_datos.ipynb'
